# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
#launch url
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(1,5):
    print(index)
    url = "https://www.myntra.com/men-casual-trousers"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='product-productMetaInfo']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 200

# %%
print(all_section[2])
# Out:
# ESPRIT
# Men Slim Fit Regular Trousers
# Rs. 3359Rs. 5599(40% OFF)

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,200),columns=['Product name','description',' price'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #Product name
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #description
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #price
    except IndexError:
        df.iloc[idx,2]=np.nan

# %%
df
# Out:
#                   Product name                        description  \
# 0    United Colors of Benetton            Men Slim Chino Trousers
# 1              U.S. Polo Assn.                Men Slim Fit Chinos
# 2                       ESPRIT      Men Slim Fit Regular Trousers
# 3                     HERE&NOW                Men Slim Fit Chinos
# 4    United Colors of Benetton                Men Slim Fit Chinos
# 5              U.S. Polo Assn.                         Men Chinos
# 6                       ESPRIT  Men Straight Fit Regular Trousers
# 7                     HERE&NOW                Men Slim Fit Chinos
# 8    United Colors of Benetton                Men Slim Fit Chinos
# 9              U.S. Polo Assn.                Men Slim Fit Chinos
# 10                Mr Bowerbird       1941 Vintage Repaired Chinos
# 11                    HERE&NOW                Men Slim Fit Chinos
# 12   United Colors of Benetton                Men Slim Fit Chinos
# ...

# %%
df.to_excel('/Users/Arjun D H/Documents/myntra_product.xlsx',header=True)
