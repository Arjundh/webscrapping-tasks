# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(1,5):
    print(index)
    url = "https://www.reliancedigital.in/laptops/c/S101210?searchQuery=:relevance:brand:D014&page=0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='sp__product']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 96

# %%
print(all_section[0])
# Out:
# Apple 33.78 cm (13.3 inch) MacBook Pro Laptop (Core i5/2.3 GHz/8 GB/128 GB), Space Grey
# ₹112,990

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,96),columns=['Product name',' price'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #Product name
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #price
    except IndexError:
        df.iloc[idx,1]=np.nan

# %%
df
# Out:
#                                          Product name                 price
# 0   Apple 33.78 cm (13.3 inch) MacBook Pro Laptop ...              ₹112,990
# 1   Apple 33.78 cm (13.3 inch) MacBook Air Laptop ...  Offer Price: ₹72,000
# 2   Apple 33.78 cm (13.3 inch) MacBook Air Laptop ...              ₹114,990
# 3   Apple 33.782 cm (13.3 inch) MacBook Pro Laptop...              ₹189,900
# 4   Apple 33.782 cm (13.3 inch) MacBook Pro Laptop...              ₹169,900
# 5   Apple 33.78 cm (13.3 inch) MacBook Pro Laptop ...              ₹119,900
# 6   Apple 38.1 cm (15 inch) MacBook Pro Laptop (Co...              ₹239,900
# 7   Apple 38.1 cm (15 inch) MacBook Pro Laptop (Co...              ₹239,900
# 8   Apple 38.1 cm (15 inch) MacBook Pro Laptop (Co...              ₹199,900
# 9   Apple 38.1 cm (15 inch) MacBook Pro Laptop (Co...              ₹199,900
# 10  Apple 33.78 cm (13.3 inch) MacBook Pro Laptop ...              ₹179,900
# ...

# %%
df.to_excel('/Users/Arjun D H/Documents/reliance_digital_product.xlsx',header=True)
