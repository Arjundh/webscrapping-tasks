# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
#launch url
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url ="https://www.monsterindia.com/search/walkin-jobs"+str(index)+"0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='card-apply-content']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 125

# %%
print(all_section[0])
# Out:
# Product Development
# Monsterindia.com
# Kozhikode / Calicut
# 2-5 Years
# Not Specified
# Job Description Industry: IT/Computers - Software Function: IT Roles: Software Engineer/ Programmer Skills: Soap/ API / database
# Skills : Marketing Manager, Group product manager, Marketing Executive

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,125),columns=['job_Role','company','location','experience','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #job_role
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #company
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #location
    except IndexError:
        df.iloc[idx,2]=np.nan
    try:
        df.iloc[idx,3]=scn[3] #experience
    except IndexError:
        df.iloc[idx,3]=np.nan
    try:
        df.iloc[idx,4]=scn[4] #description
    except IndexError:
        df.iloc[idx,4]=np.nan

# %%
df
# Out:
#                                               job_Role  \
# 0                                  Product Development
# 1    Walk IN For GENERAL EMBEDDED on 13-07-2019 at ...
# 2    Walk IN For GENERAL EMBEDDED on July 13, 2019 ...
# 3                  Mega drive for Freshers For Top MNC
# 4      Walk IN For Autosar on July 13, 2019 at Chennai
# 5    Walk-in @ STG Infotech for Java/J2ee Professio...
# 6          Walk IN For CAN on July 13, 2019 at Chennai
# 7                       IT Recruiter / Sr.IT Recruiter
# 8    Mega Drive for Tata Aia Life/Induslnd bank/Rel...
# 9    Walk-in Freshers For JAVA PROGRAMMERS on 13th ...
# 10   Immediate Opening for IT Network Analyst in Ca...
# 11          Telecaller for Leading Real Estate Company
# 12       Customer Support Executive for top MNC in HYD
# 13   Walk in for Freshers-2016, 2017, 2018 and 2019...
# 14   Freshers Walk-in For Software Operations Execu...
# 15   Walk IN For CAN on 13-07-2019 at Chennai 10:00...
# 16                Walk in for Freshers- US Recruitment
# 17   Walk-in Freshers For C/C++ PROGRAMMERS on 13th...
# 18   Cognizant is hiring Freshers for Junior Data A...
# 19                           Data Processing Executive
# 20                          Software Developer Fresher
# 21   Exciting opportunity for .NET professionals-TE...
# 22   Walk-in Drive- Xavient – Automation Testing (S...
# 23           Vacancies for Site Engineer on 10/03/2019
# 24                                        HR RECRUITER
# 25                                 Product Development
# 26   Walk IN For GENERAL EMBEDDED on 13-07-2019 at ...
# 27   Walk IN For GENERAL EMBEDDED on July 13, 2019 ...
# 28                 Mega drive for Freshers For Top MNC
# 29     Walk IN For Autosar on July 13, 2019 at Chennai
# ..                                                 ...
# 95                          Software Developer Fresher
# 96   Exciting opportunity for .NET professionals-TE...
# 97   Walk-in Drive- Xavient – Automation Testing (S...
# 98   Walk in for lab assistants in CSE ECE EEE CIVI...
# 99           Vacancies for Site Engineer on 10/03/2019
# 100                                Product Development
# 101  Walk IN For GENERAL EMBEDDED on 13-07-2019 at ...
# 102  Walk IN For GENERAL EMBEDDED on July 13, 2019 ...
# 103                Mega drive for Freshers For Top MNC
# 104    Walk IN For Autosar on July 13, 2019 at Chennai
# 105  Walk-in @ STG Infotech for Java/J2ee Professio...
# 106        Walk IN For CAN on July 13, 2019 at Chennai
# 107                     IT Recruiter / Sr.IT Recruiter
# 108  Mega Drive for Tata Aia Life/Induslnd bank/Rel...
# 109  Walk-in Freshers For JAVA PROGRAMMERS on 13th ...
# 110  Immediate Opening for IT Network Analyst in Ca...
# 111         Telecaller for Leading Real Estate Company
# 112      Customer Support Executive for top MNC in HYD
# 113  Walk in for Freshers-2016, 2017, 2018 and 2019...
# 114  Freshers Walk-in For Software Operations Execu...
# 115  Walk IN For CAN on 13-07-2019 at Chennai 10:00...
# 116               Walk in for Freshers- US Recruitment
# 117  Walk-in Freshers For C/C++ PROGRAMMERS on 13th...
# 118  Cognizant is hiring Freshers for Junior Data A...
# 119                          Data Processing Executive
# 120                         Software Developer Fresher
# 121  Exciting opportunity for .NET professionals-TE...
# 122  Walk-in Drive- Xavient – Automation Testing (S...
# 123          Vacancies for Site Engineer on 10/03/2019
# 124                                       HR RECRUITER
#
#                                               company  \
# 0                                    Monsterindia.com
# 1                     Jasmin Infotech Private Limited
# 2                     Jasmin Infotech Private Limited
# 3               Hucon Solutions India Private Limited
# 4                     Jasmin Infotech Private Limited
# 5                              Stg Infotech India LLP
# 6                     Jasmin Infotech Private Limited
# 7        Screatives Software Services Private Limited
# 8                                     Hr Remedy India
# 9        Betamonks Technology Factory Private Limited
# 10         Cameo Global Communication Private Limited
# 11           Rabil Infotech Solutions Private Limited
# 12                         Stryde Consulting Services
# 13               Freelancer Tirunalla Venkateswra Rao
# 14       Betamonks Technology Factory Private Limited
# 15                    Jasmin Infotech Private Limited
# 16       Ionidea Enterprise Solutions Private Limited
# 17       Betamonks Technology Factory Private Limited
# 18       Cognizant Technology Solutions India Pvt Ltd
# 19                  INS Data Services Private Limited
# 20              Hudson Agile Ventures Private Limited
# 21                     Saggezza India Private Limited
# 22   Xavient Software Solutions India Private Limited
# 23                                 BHARAT INSTITUTION
# 24                             Trans Gnx HR Solutions
# 25                                   Monsterindia.com
# 26                    Jasmin Infotech Private Limited
# 27                    Jasmin Infotech Private Limited
# 28              Hucon Solutions India Private Limited
# 29                    Jasmin Infotech Private Limited
# ..                                                ...
# 95              Hudson Agile Ventures Private Limited
# 96                     Saggezza India Private Limited
# 97   Xavient Software Solutions India Private Limited
# 98                                 BHARAT INSTITUTION
# 99                                 BHARAT INSTITUTION
# 100                                  Monsterindia.com
# 101                   Jasmin Infotech Private Limited
# 102                   Jasmin Infotech Private Limited
# 103             Hucon Solutions India Private Limited
# 104                   Jasmin Infotech Private Limited
# 108  Mumbai, Mumbai City, Navi Mumbai, Thane      0-5 Years
# 109                                  Chennai  Not Specified
# 110                    Bengaluru / Bangalore  Not Specified
# 111                 Hyderabad / Secunderabad      0-3 Years
# 112                 Hyderabad / Secunderabad      0-1 Years
# 113                 Hyderabad / Secunderabad      0-1 Years
# 114                                  Chennai  Not Specified
# 115                                  Chennai      2-6 Years
# 116                    Bengaluru / Bangalore  Not Specified
# 117                                  Chennai  Not Specified
# 118                                  Kolkata      0-1 Years
# 119                           Tiruvannamalai      0-3 Years
# 120                    Bengaluru / Bangalore  Not Specified
# 121                    Bengaluru / Bangalore     7-12 Years
# 122                                    Noida      3-8 Years
# 123                 Hyderabad / Secunderabad      2-7 Years
# 124                                  Chennai  Not Specified
#
#                                            description
# 0                                        Not Specified
# 1                                        Not Specified
# 2                                        Not Specified
# 3    Grab The opportunity, Mega drive for Internati...
# 4                                        Not Specified
# 5                                        Not Specified
# 6                                        Not Specified
# 7                                        Not Specified
# 8                                        Not Specified
# 9    Responsibilities: • Design, build, and maintai...
# 10   Your interview for the IT ANALYST role with Ca...
# 11                                       Not Specified
# 12                                       Not Specified
# 13                                       Not Specified
# 14   Responsibilities and Duties Monitoring and mai...
# 15                                       Not Specified
# 16   Responsibilities: Source and screen the candid...
# 17   Responsibilities: • Design, build, and maintai...
# 18                                       Not Specified
# 19                                       Not Specified
# 20   We are looking for some freshers to work on Ph...
# 21                                       Not Specified
# 22                                       Not Specified
# 23                                       Not Specified
# 24   Are you a passionate HR aspirant, looking forw...
# 25                                       Not Specified
# 26                                       Not Specified
# 27                                       Not Specified
# 28   Grab The opportunity, Mega drive for Internati...
# 29                                       Not Specified
# ..                                                 ...
# 95   We are looking for some freshers to work on Ph...
# 96                                       Not Specified
# 97                                       Not Specified
# 98                                       Not Specified
# 99                                       Not Specified
# 100                                      Not Specified
# 101                                      Not Specified
# 102                                      Not Specified
# 103  Grab The opportunity, Mega drive for Internati...
# 104                                      Not Specified
# 105                                      Not Specified
# 106                                      Not Specified
# 107                                      Not Specified
# 108                                      Not Specified
# 109  Responsibilities: • Design, build, and maintai...
# 110  Your interview for the IT ANALYST role with Ca...
# 111                                      Not Specified
# 112                                      Not Specified
# 113                                      Not Specified
# 114  Responsibilities and Duties Monitoring and mai...
# 115                                      Not Specified
# 116  Responsibilities: Source and screen the candid...
# 117  Responsibilities: • Design, build, and maintai...
# 118                                      Not Specified
# 119                                      Not Specified
# 120  We are looking for some freshers to work on Ph...
# 121                                      Not Specified
# 122                                      Not Specified
# 123                                      Not Specified
# 124  Are you a passionate HR aspirant, looking forw...
#
# [125 rows x 5 columns]

# %%
df.to_excel('/Users/Arjun D H/Documents/jobs_role_description.xlsx',header=True)
