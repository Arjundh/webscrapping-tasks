# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url = "https://www.mouthshut.com/websites/Swiggy-com-reviews-925740914"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='col-10 review']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 100

# %%
print(all_section[0])
# Out:
# Absolute disappointing & disastrous experience.
# few seconds agoRead
# This is about yesterday’s food order with Swiggy to Bowl Company. I place my order at 11.40 am, and it showed 45 mins.At around 12.30 pm delivery executive calls me to ask can he bring the order via auto as it is a bulk order and cannot be carried on the bike. I agreed to pay the auto charge...Read More
# Reply As Brand
# Like
# (0)Comments (0)

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,100),columns=['review','posted_time','experience'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #review
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #posted_time
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #experience
    except IndexError:
        df.iloc[idx,2]=np.nan

# %%
df
# Out:
#                                                review  \
# 0     Absolute disappointing & disastrous experience.
# 1                                    Pathetic service
# 2                  Third class food and customer care
# 3   Very worst delivery service & Customer experience
# 4             Poor Management, unprofessional service
# 5                     Guaranteed Recipe for death!!!!
# 6                 Pathetic food delivery app ever....
# 7       Worst Customer Support (Order No: 1188229831)
# 8                 I odrered from first and last time.
# 9      “Swiggy review”disgusting fraud made by swiggy
# 10                             Worst Customer Service
# 11    Worst ever support and service very incompetent
# 12                                 Fraud delivery boy
# 13  Order mixup, some orders missing, now they cancel
# 14                                       Order cancel
# 15                            Worst service ever seen
# 16                            Never order from Swiggy
# 17                           Found dead worms in food
# 18                        Worst Swiggy job experience
# 19                    Swiggy- Needs to be transparent
# 20    Absolute disappointing & disastrous experience.
# 21                                   Pathetic service
# 22                 Third class food and customer care
# 23  Very worst delivery service & Customer experience
# 24            Poor Management, unprofessional service
# 25                    Guaranteed Recipe for death!!!!
# 26                Pathetic food delivery app ever....
# 27      Worst Customer Support (Order No: 1188229831)
# 28                I odrered from first and last time.
# 29     “Swiggy review”disgusting fraud made by swiggy
# ..                                                ...
# 70                             Worst Customer Service
# 71    Worst ever support and service very incompetent
# 72                                 Fraud delivery boy
# 73  Order mixup, some orders missing, now they cancel
# 74                                       Order cancel
# 75                            Worst service ever seen
# 76                            Never order from Swiggy
# 77                           Found dead worms in food
# 78                        Worst Swiggy job experience
# 79                    Swiggy- Needs to be transparent
# 80    Absolute disappointing & disastrous experience.
# 81                                   Pathetic service
# 82                 Third class food and customer care
# 83  Very worst delivery service & Customer experience
# 84            Poor Management, unprofessional service
# 85                    Guaranteed Recipe for death!!!!
# 86                Pathetic food delivery app ever....
# 87      Worst Customer Support (Order No: 1188229831)
# 88                I odrered from first and last time.
# 89     “Swiggy review”disgusting fraud made by swiggy
# 90                             Worst Customer Service
# 91    Worst ever support and service very incompetent
# 92                                 Fraud delivery boy
# 93  Order mixup, some orders missing, now they cancel
# 94                                       Order cancel
# 95                            Worst service ever seen
# 96                            Never order from Swiggy
# 97                           Found dead worms in food
# 98                        Worst Swiggy job experience
# 99                    Swiggy- Needs to be transparent
#
#                                     posted_time  \
# 0                           few seconds agoRead
# 1             7 hrs 9 mins agoRead (via Mobile)
# 2                    1 day agoRead (via Mobile)
# 3                     Feb 12, 2019 03:04 PMRead
# 4                     Nov 03, 2018 12:53 AMRead
# 5              Oct 18, 2018 07:12 PM12959 Views
# 6                     Sep 28, 2018 04:39 PMRead
# 7                     Jun 01, 2018 05:52 PMRead
# 8              4 days agoRead (via Android App)
# 9                   5 days agoRead (via Mobile)
# 10                 16 days agoRead (via Mobile)
# 11                              19 days agoRead
# 12                              20 days agoRead
# 13                 20 days agoRead (via Mobile)
# 14                 21 days agoRead (via Mobile)
# 15                 23 days agoRead (via Mobile)
# 16                 23 days agoRead (via Mobile)
# 17                 24 days agoRead (via Mobile)
# 18  Jun 16, 2019 12:40 PMRead (via Android App)
# 19       Jun 09, 2019 02:25 PMRead (via Mobile)
# 20                          few seconds agoRead
# 21            7 hrs 9 mins agoRead (via Mobile)
# 22                   1 day agoRead (via Mobile)
# 23                    Feb 12, 2019 03:04 PMRead
# 24                    Nov 03, 2018 12:53 AMRead
# 25             Oct 18, 2018 07:12 PM12960 Views
# 26             Sep 28, 2018 04:39 PM15412 Views
# 27             Jun 01, 2018 05:52 PM15775 Views
# 28        4 days ago348 Views (via Android App)
# 29             5 days ago536 Views (via Mobile)
# ..                                          ...
# 70                 16 days agoRead (via Mobile)
# 71                              19 days agoRead
# 72                              20 days agoRead
# 73                 20 days agoRead (via Mobile)
# 74                 21 days agoRead (via Mobile)
# 75                 23 days agoRead (via Mobile)
# 76                 23 days agoRead (via Mobile)
# 77                 24 days agoRead (via Mobile)
# 78  Jun 16, 2019 12:40 PMRead (via Android App)
# 79       Jun 09, 2019 02:25 PMRead (via Mobile)
# 80                          few seconds agoRead
# 81            7 hrs 9 mins agoRead (via Mobile)
# 82                   1 day agoRead (via Mobile)
# 83                    Feb 12, 2019 03:04 PMRead
# 84                    Nov 03, 2018 12:53 AMRead
# 85                    Oct 18, 2018 07:12 PMRead
# 86                    Sep 28, 2018 04:39 PMRead
# 87                    Jun 01, 2018 05:52 PMRead
# 88             4 days agoRead (via Android App)
# 89                  5 days agoRead (via Mobile)
# 90                 16 days agoRead (via Mobile)
# 91                              19 days agoRead
# 92                              20 days agoRead
# 93                 20 days agoRead (via Mobile)
# 94                 21 days agoRead (via Mobile)
# 95                 23 days agoRead (via Mobile)
# 96                 23 days agoRead (via Mobile)
# 97                 24 days agoRead (via Mobile)
# 98  Jun 16, 2019 12:40 PMRead (via Android App)
# 99       Jun 09, 2019 02:25 PMRead (via Mobile)
#
#                                            experience
# 0   This is about yesterday’s food order with Swig...
# 1   Swiggy customer support is pathetic. They do n...
# 2   GOT plastic in the food ordered.I really think...
# 3   I ordered Swiggy on 12-02-2019. Basically, I'm...
# 4   Firstly I want to say that having a service li...
# 5   Has anybody ever seen the Swiggy riders in Ban...
# 6   Yes, after reading my review you will agree wi...
# 7   I had placed an order on 27th May which was de...
# 8   Hello world I found mouthshut during my search...
# 9   I am ravi giving bad review on Swiggy due to f...
# 10  I had ordered the sub by using this app and go...
# 11  I taking time to how upset and shameful swiggy...
# 12  Hi yesterday I ordered food from Swiggy and ma...
# 13  Worst service by swiggy. They mixup orders, so...
# 14  I placed order for sweets and it got cancelled...
# 15  Have ordered and after sometime it’s shown as ...
# 16  Today , we placed an order from a renowned res...
# 17  I have dead worms in my food am customer from ...
# 18  Dear all, since I completed 6 months in swiggy...
# 19  I had offered food through Swiggy around 12.30...
# 20  This is about yesterday’s food order with Swig...
# 21  Swiggy customer support is pathetic. They do n...
# 22  GOT plastic in the food ordered.I really think...
# 23  I ordered Swiggy on 12-02-2019. Basically, I'm...
# 24  Firstly I want to say that having a service li...
# 25  Has anybody ever seen the Swiggy riders in Ban...
# 26  Yes, after reading my review you will agree wi...
# 27  I had placed an order on 27th May which was de...
# 28  Hello world I found mouthshut during my search...
# 29  I am ravi giving bad review on Swiggy due to f...
# ..                                                ...
# 70  I had ordered the sub by using this app and go...
# 71  I taking time to how upset and shameful swiggy...
# 72  Hi yesterday I ordered food from Swiggy and ma...
# 73  Worst service by swiggy. They mixup orders, so...
# 74  I placed order for sweets and it got cancelled...
# 75  Have ordered and after sometime it’s shown as ...
# 76  Today , we placed an order from a renowned res...
# 77  I have dead worms in my food am customer from ...
# 78  Dear all, since I completed 6 months in swiggy...
# 79  I had offered food through Swiggy around 12.30...
# 80  This is about yesterday’s food order with Swig...
# 81  Swiggy customer support is pathetic. They do n...
# 82  GOT plastic in the food ordered.I really think...
# 83  I ordered Swiggy on 12-02-2019. Basically, I'm...
# 84  Firstly I want to say that having a service li...
# 85  Has anybody ever seen the Swiggy riders in Ban...
# 86  Yes, after reading my review you will agree wi...
# 87  I had placed an order on 27th May which was de...
# 88  Hello world I found mouthshut during my search...
# 89  I am ravi giving bad review on Swiggy due to f...
# 90  I had ordered the sub by using this app and go...
# 91  I taking time to how upset and shameful swiggy...
# 92  Hi yesterday I ordered food from Swiggy and ma...
# 93  Worst service by swiggy. They mixup orders, so...
# 94  I placed order for sweets and it got cancelled...
# 95  Have ordered and after sometime it’s shown as ...
# 96  Today , we placed an order from a renowned res...
# 97  I have dead worms in my food am customer from ...
# 98  Dear all, since I completed 6 months in swiggy...
# 99  I had offered food through Swiggy around 12.30...
#
# [100 rows x 3 columns]

# %%
df.to_excel('/Users/Arjun D H/Documents/review_swiggy.xlsx',header=True)
