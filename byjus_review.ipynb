# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url = "https://www.mouthshut.com/product-reviews/BYJUS-The-Learning-App-reviews-925899219"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='col-10 review']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 100

# %%
print(all_section[8])
# Out:
# Learning app
# Mar 22, 2019 10:53 AMRead (via Android App)
# This learning application helps you in every time every where .this app is really too good and I have an experience of 2 years of BUJU'S -The Learning app.Clear your doubt in few second . you will find your teachers on this app and ask your doubt and best teachers on that topic clear...Read More
# Reply As Brand
# Like
# (0)Comments (1)

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,100),columns=['review','posted_time','experience'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #review
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #posted_time
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #experience
    except IndexError:
        df.iloc[idx,2]=np.nan

# %%
df
# Out:
#                                                review  \
# 0     Review about executive who gave demo of product
# 1   One of the best online learning app in free of...
# 2                                   Best learning app
# 3                                   Best learning app
# 4                                   Best learning aap
# 5                               The best learning app
# 6                                 Byju -the great aap
# 7       Easy to understand any problems in studies!!!
# 8                                        Learning app
# 9                            BYJU'S -THE LEARNING APP
# 10                            Byju's the learning app
# 11                                      Wonderful App
# 12                                 Excellent for kids
# 13                               Best way of learning
# 14                                    Learning friend
# 15                   The best way to learn everything
# 16                        Learning with Tab Byjus Way
# 17                               Contents in this app
# 18                 Byju"s ...No 1 learning online App
# 19                               Best online learning
# 20    Review about executive who gave demo of product
# 21  One of the best online learning app in free of...
# 22                                  Best learning app
# 23                                  Best learning app
# 24                                  Best learning aap
# 25                              The best learning app
# 26                                Byju -the great aap
# 27      Easy to understand any problems in studies!!!
# 28                                       Learning app
# 29                           BYJU'S -THE LEARNING APP
# ..                                                ...
# 70                            Byju's the learning app
# 71                                      Wonderful App
# 72                                 Excellent for kids
# 73                               Best way of learning
# 74                                    Learning friend
# 75                   The best way to learn everything
# 76                        Learning with Tab Byjus Way
# 77                               Contents in this app
# 78                 Byju"s ...No 1 learning online App
# 79                               Best online learning
# 80    Review about executive who gave demo of product
# 81  One of the best online learning app in free of...
# 82                                  Best learning app
# 83                                  Best learning app
# 84                                  Best learning aap
# 85                              The best learning app
# 86                                Byju -the great aap
# 87      Easy to understand any problems in studies!!!
# 88                                       Learning app
# 89                           BYJU'S -THE LEARNING APP
# 90                            Byju's the learning app
# 91                                      Wonderful App
# 92                                 Excellent for kids
# 93                               Best way of learning
# 94                                    Learning friend
# 95                   The best way to learn everything
# 96                        Learning with Tab Byjus Way
# 97                               Contents in this app
# 98                 Byju"s ...No 1 learning online App
# 99                               Best online learning
#
#                                           posted_time  \
# 0                                     19 days agoRead
# 1                   22 days agoRead (via Android App)
# 2         Jun 24, 2019 01:39 PMRead (via Android App)
# 3              Jun 15, 2019 03:21 PMRead (via Mobile)
# 4         May 12, 2019 12:18 PMRead (via Android App)
# 5         May 07, 2019 03:18 PMRead (via Android App)
# 6         May 04, 2019 06:17 PMRead (via Android App)
# 7         Apr 09, 2019 10:59 PMRead (via Android App)
# 8         Mar 22, 2019 10:53 AMRead (via Android App)
# 9         Mar 18, 2019 03:27 PMRead (via Android App)
# 10        Feb 10, 2019 02:54 PMRead (via Android App)
# 11        Feb 05, 2019 06:05 PMRead (via Android App)
# 12            Feb 01, 2019 04:28 PMRead (via iOS App)
# 13            Jan 06, 2019 10:01 PMRead (via iOS App)
# 14        Dec 20, 2018 01:18 PMRead (via Android App)
# 15        Dec 17, 2018 08:56 PMRead (via Android App)
# 16                          Dec 02, 2018 10:12 PMRead
# 17        Nov 15, 2018 05:33 PMRead (via Android App)
# 18                          Oct 03, 2018 12:11 PMRead
# 19        Sep 05, 2018 12:45 PMRead (via Android App)
# 20                                    19 days agoRead
# 21                  22 days agoRead (via Android App)
# 22        Jun 24, 2019 01:39 PMRead (via Android App)
# 23       Jun 15, 2019 03:21 PM5772 Views (via Mobile)
# 24  May 12, 2019 12:18 PM8931 Views (via Android App)
# 25  May 07, 2019 03:18 PM9716 Views (via Android App)
# 26  May 04, 2019 06:17 PM8257 Views (via Android App)
# 27  Apr 09, 2019 10:59 PM10766 Views (via Android ...
# 28  Mar 22, 2019 10:53 AM12470 Views (via Android ...
# 29  Mar 18, 2019 03:27 PM11883 Views (via Android ...
# ..                                                ...
# 70        Feb 10, 2019 02:54 PMRead (via Android App)
# 71        Feb 05, 2019 06:05 PMRead (via Android App)
# 72            Feb 01, 2019 04:28 PMRead (via iOS App)
# 73            Jan 06, 2019 10:01 PMRead (via iOS App)
# 74        Dec 20, 2018 01:18 PMRead (via Android App)
# 75  Dec 17, 2018 08:56 PM16013 Views (via Android ...
# 76                   Dec 02, 2018 10:12 PM15291 Views
# 77  Nov 15, 2018 05:33 PM16909 Views (via Android ...
# 78                   Oct 03, 2018 12:11 PM14116 Views
# 79  Sep 05, 2018 12:45 PM13889 Views (via Android ...
# 80                                    19 days agoRead
# 81                  22 days agoRead (via Android App)
# 82        Jun 24, 2019 01:39 PMRead (via Android App)
# 83             Jun 15, 2019 03:21 PMRead (via Mobile)
# 84        May 12, 2019 12:18 PMRead (via Android App)
# 85        May 07, 2019 03:18 PMRead (via Android App)
# 86        May 04, 2019 06:17 PMRead (via Android App)
# 87        Apr 09, 2019 10:59 PMRead (via Android App)
# 88        Mar 22, 2019 10:53 AMRead (via Android App)
# 89        Mar 18, 2019 03:27 PMRead (via Android App)
# 90        Feb 10, 2019 02:54 PMRead (via Android App)
# 91        Feb 05, 2019 06:05 PMRead (via Android App)
# 92     Feb 01, 2019 04:28 PM13696 Views (via iOS App)
# 93            Jan 06, 2019 10:01 PMRead (via iOS App)
# 94  Dec 20, 2018 01:18 PM13354 Views (via Android ...
# 95  Dec 17, 2018 08:56 PM16014 Views (via Android ...
# 96                   Dec 02, 2018 10:12 PM15292 Views
# 97  Nov 15, 2018 05:33 PM16910 Views (via Android ...
# 98                   Oct 03, 2018 12:11 PM14117 Views
# 99  Sep 05, 2018 12:45 PM13890 Views (via Android ...
#
#                                            experience
# 0   I really want to thank BYJU'S Learning App, wh...
# 1   If you are finding best learning app then youb...
# 2   Very easy to understand concepts and clear con...
# 3   Very easy to understand hard part of the subje...
# 4   This aap is best learning aap . This app to he...
# 5   This is a revolutionary learning app ever I se...
# 6   This aap is very great for learning. With the ...
# 7   With the help of this app , I understand probl...
# 8   This learning application helps you in every t...
# 9   This is the very fast growing education app in...
# 10  The education can empower our life.In the onli...
# 11  This byju's app is the best learning app ever ...
# 12  I bought this app for my sisters kids not am e...
# 13  This is the best way of learning. It helps to ...
# 14  Perfect appboth the classrooms and instractor ...
# 15  One year ago my friend suggested me this learn...
# 16  I bought one for my brothers kids abroad. even...
# 17  Hello friends it"s Naman Singh Sharma. I am go...
# 18  Very very useful app.My son is using this app ...
# 19  The product is very awesome, if you choose big...
# 20  I really want to thank BYJU'S Learning App, wh...
# 21  If you are finding best learning app then youb...
# 22  Very easy to understand concepts and clear con...
# 23  Very easy to understand hard part of the subje...
# 24  This aap is best learning aap . This app to he...
# 25  This is a revolutionary learning app ever I se...
# 26  This aap is very great for learning. With the ...
# 27  With the help of this app , I understand probl...
# 28  This learning application helps you in every t...
# 29  This is the very fast growing education app in...
# ..                                                ...
# 70  The education can empower our life.In the onli...
# 71  This byju's app is the best learning app ever ...
# 72  I bought this app for my sisters kids not am e...
# 73  This is the best way of learning. It helps to ...
# 74  Perfect appboth the classrooms and instractor ...
# 75  One year ago my friend suggested me this learn...
# 76  I bought one for my brothers kids abroad. even...
# 77  Hello friends it"s Naman Singh Sharma. I am go...
# 78  Very very useful app.My son is using this app ...
# 79  The product is very awesome, if you choose big...
# 80  I really want to thank BYJU'S Learning App, wh...
# 81  If you are finding best learning app then youb...
# 82  Very easy to understand concepts and clear con...
# 83  Very easy to understand hard part of the subje...
# 84  This aap is best learning aap . This app to he...
# 85  This is a revolutionary learning app ever I se...
# 86  This aap is very great for learning. With the ...
# 87  With the help of this app , I understand probl...
# 88  This learning application helps you in every t...
# 89  This is the very fast growing education app in...
# 90  The education can empower our life.In the onli...
# 91  This byju's app is the best learning app ever ...
# 92  I bought this app for my sisters kids not am e...
# 93  This is the best way of learning. It helps to ...
# 94  Perfect appboth the classrooms and instractor ...
# 95  One year ago my friend suggested me this learn...
# 96  I bought one for my brothers kids abroad. even...
# 97  Hello friends it"s Naman Singh Sharma. I am go...
# 98  Very very useful app.My son is using this app ...
# 99  The product is very awesome, if you choose big...
#
# [100 rows x 3 columns]

# %%
df.to_excel('/Users/Arjun D H/Documents/review_byjus_learning_app.xlsx',header=True)
