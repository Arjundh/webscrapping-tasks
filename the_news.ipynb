# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
#launch url
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url ="https://www.thehindu.com/news/national/?utm_source=google&utm_medium=cpc&utm_campaign=national-th&gclid=CjwKCAjwscDpBRBnEiwAnQ0HQEs-qNkTaSIOGTKHwIC__tE53cQXhWCONX1fTIPVX8tLt7MUadtUqRoCfwQQAvD_BwE"+str(index)+"0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='Other-StoryCard']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 210

# %%
print(all_section[2])
# Out:
# No First Use policy a good position to keep: Dr. Chidambaram
# India’s declared No First Use (NFU) policy on nuclear weapons as part of its nuclear doctrine is a “good position” to keep, Dr. R. Chidambaram, one

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,210),columns=['head_line','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #head_line
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #description
    except IndexError:
        df.iloc[idx,1]=np.nan

# %%
df
# Out:
#                                              head_line  \
# 0    Parliament proceedings live | 'Ambani is a per...
# 1    Nagaland RIIN: Meet resolves to make policies ...
# 2    No First Use policy a good position to keep: D...
# 3                   ‘Use more steel for water mission’
# 4    AAI has 26 unused airports across the country,...
# 5                        Ayodhya panel seeks more time
# 6    Judiciary should revisit conventional wisdom: CJI
# 7               Normal rainfall measure may be lowered
# 8    Kulbhushan Jadhav case: ‘Indian stand vindicat...
# 9    Review Kulbhushan Jadhav sentence, grant consu...
# 10   We want him back soon, say Kulbhushan Jadhav’s...
# 11              Green light for three railway projects
# 12        Bombay HC convicts man for U.K. teen’s death
# 13   Karnataka rebels case: Congress divided over S...
# 14                  Dam Safety Bill gets nod from CCEA
# 15                    Tiranga TV employees end protest
# ...

# %%
df.to_excel('/Users/Arjun D H/Documents/the_news.xlsx',header=True)
