# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
#launch url
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url ="https://www.ndtv.com/latest?pfrom=home-mainnavgation"+str(index)+"0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='new_storylising_contentwrap']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 75

# %%
print(all_section[2])
# Out:
# Wimbledon 2019 Semi Final: Novak Djokovic Hopes To End Roberto Bautista Agut's Winning Run
# Prakash Rai | Friday July 12, 2019
# Wimbledon 2019 Semi Final Live: Roger Federer vs Rafael Nadal, Novak Djokovic vs Roberto Bautista Agut Tennis Score; Semifinal Final Match: Novak Djokovic will be eyeing his successive Wimbledon title.

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,75),columns=['head_line','written_dated','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #head_line
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #written_dated
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #dated
    except IndexError:
        df.iloc[idx,2]=np.nan

# %%
df
# Out:
#                                             head_line  \
# 0   Fodder Scam: Lalu Yadav Gets Bail In Deoghar T...
# 1   TGIF, Because Tusshar Kapoor Shared A Really C...
# 2   Wimbledon 2019 Semi Final: Novak Djokovic Hope...
# 3   Indian Cooking Hacks: How To Make Restaurant-S...
# 4   4 Rebel Lawmakers From Karnataka Visit Siddhiv...
# 5   YouTube Introduces Learning Playlists Without ...
# 6   Samsung Galaxy Note 10, Galaxy Note10+ Price f...
# 7   Sigma fp Full-Frame Mirrorless Camera Launched...
# 8                          Government Aims To Raise R
# 9   Housing Becomes More Expensive, Mumbai Least A...
# 10  10.or G2 Price in India Revealed Ahead of Amaz...
# 11  Call of Duty: Modern Warfare’s Gunfight Mode R...
# 12  Dhapate: The High-Protein High-Fibre Mixed Gra...
# 13  Amitabh Bachchan's Saand Ki Aankh Tweet Will M...
# 14  Vivo Z1 Pro Next Sale in India Set for July 16...
# 15  Fodder Scam: Lalu Yadav Gets Bail In Deoghar T...
# ...

# %%
df.to_excel('/Users/Arjun D H/Documents/news_description.xlsx',header=True)
